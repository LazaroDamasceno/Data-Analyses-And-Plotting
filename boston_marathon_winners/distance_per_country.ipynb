# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Mens_Boston_Marathon_Winners.csv")
df_cleaned = df.dropna()

# %%
df_grouped = df_cleaned.groupby('Country')['Distance (KM)'].sum().reset_index()

# %%
df_sorted = df_grouped.sort_values(by=('Distance (KM)'), ascending=False)
df_sorted = df_sorted.reset_index()
df_sorted = df_sorted.drop(columns=['index'])
df_sorted = df_sorted.rename(columns={'Distance (KM)': 'Distance'})

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.barplot(
    data=df_sorted,
    x='Distance',
    y='Country',
    orient='h'
)

ax.set_title("Total Distance By Countries: Male Runners ", fontweight="bold")
ax.bar_label(ax.containers[0], fmt="%.0f")
ax.set_ylabel("")
ax.xaxis.set_visible(False)
ax.spines[['top', 'right', 'bottom']].set_visible(False)

plt.tight_layout()
plt.show()
