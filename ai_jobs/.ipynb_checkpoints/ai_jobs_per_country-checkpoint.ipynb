# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ai_job_dataset.csv')

# %%
df_cleaned = df.dropna()

# %%
df_grouped = df_cleaned.groupby('company_location')['job_title']
df_grouped = df_grouped.size()
df_grouped = df_grouped.reset_index(name='value')

# %%
df_sorted = df_grouped.sort_values(by=('value'), ascending=False)
df_sorted = df_sorted.reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 8))

sns.barplot(data=df_sorted, ax=ax, orient='h', x='value', y='company_location')

ax.set_title("AI Jobs By Country", fontweight="bold")
ax.bar_label(ax.containers[0])
ax.set_title("", fontweight="bold")
ax.set_ylabel("")
ax.xaxis.set_visible(False)
ax.spines[['top', 'right', 'bottom']].set_visible(False)

plt.tight_layout()
plt.show()
