# %% [markdown]
# Qual a quantidade percentual de habitantes que moram nas capitais em relação a população da UF?

# %%
capitais = [
    'Aracaju',
    'Belém',
    'Belo Horizonte',
    'Boa Vista',
    'Brasília',
    'Cabo Frio',
    'Cuiabá',
    'Curitiba',
    'Fortaleza',
    'Goiânia',
    'João Pessoa',
    'Macapá',
    'Maceió',
    'Manaus',
    'Natal',
    'Palmas',
    'Recife',
    'Rio Branco',
    'Rio de Janeiro',
    'Salvador',
    'São Luís',
    'São Paulo',
    'Teresina',
    'Vitória'
]
