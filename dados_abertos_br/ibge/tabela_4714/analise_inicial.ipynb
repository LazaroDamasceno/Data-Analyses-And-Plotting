# %%
import sidrapy as sidra
import numpy as np

# %%
df = sidra.get_table(
    '4714',
    3,
    'all'
)

# %%
df.head()
# Out:
#                            NC                    NN  \
# 0  Nível Territorial (Código)     Nível Territorial
# 1                           3  Unidade da Federação
# 2                           3  Unidade da Federação
# 3                           3  Unidade da Federação
# 4                           3  Unidade da Federação
#
#                            MC                                 MN           V  \
# 0  Unidade de Medida (Código)                  Unidade de Medida       Valor
# 1                          45                            Pessoas     1581196
# 2                          26              Quilômetros quadrados  237754.172
# 3                          28  Habitante por quilômetro quadrado        6.65
# 4                          45                            Pessoas      830018
#
#                              D1C                   D1N           D2C   D2N  \
# 0  Unidade da Federação (Código)  Unidade da Federação  Ano (Código)   Ano
# ...

# %%
df = df[['D1N', 'V', 'D3N']]

# %%
df.head()
# Out:
#                     D1N           V                          D3N
# 0  Unidade da Federação       Valor                     Variável
# 1              Rondônia     1581196          População residente
# 2              Rondônia  237754.172  Área da unidade territorial
# 3              Rondônia        6.65        Densidade demográfica
# 4                  Acre      830018          População residente

# %%
df = df.iloc[1:, :].reset_index(drop=True)

# %%
df.head()
# Out:
#         D1N           V                          D3N
# 0  Rondônia     1581196          População residente
# 1  Rondônia  237754.172  Área da unidade territorial
# 2  Rondônia        6.65        Densidade demográfica
# 3      Acre      830018          População residente
# 4      Acre  164173.429  Área da unidade territorial

# %%
df = df.rename(columns={
    'D1N':  'uf',
    'V':  'valor',
    'D3N':  'variavel'
})

# %%
df.columns
# Out:
# Index(['uf', 'valor', 'variavel'], dtype='object')

# %%
df.dtypes
# Out:
# uf          object
# valor       object
# variavel    object
# dtype: object

# %%
df['valor'] = df['valor'].astype(np.float64)

# %%
df.dtypes
# Out:
# uf           object
# valor       float64
# variavel     object
# dtype: object

# %%
df['variavel'].value_counts()
# Out:
# variavel
# População residente            27
# Área da unidade territorial    27
# Densidade demográfica          27
# Name: count, dtype: int64

# %%
df.to_csv('tabela_4714_limpa.csv', index=False)
